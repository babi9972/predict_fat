# %%
import streamlit as st
import pandas as pd
import joblib

# --- بارگذاری مدل ذخیره‌شده ---
model = joblib.load("fat_percentage_predictor.joblib")

# --- عنوان اپ ---
st.title("🔮 پیش‌بینی درصد چربی بدن")
st.write("این اپ با استفاده از مدل یادگیری ماشین، درصد چربی بدن شما را پیش‌بینی می‌کند.")

# --- گرفتن ورودی‌های کاربر ---
age = st.number_input("سن (سال)", min_value=10, max_value=100, value=28)
gender = st.selectbox("جنسیت", ["Male", "Female"])
weight = st.number_input("وزن (kg)", min_value=30.0, max_value=200.0, value=80.0)
height = st.number_input("قد (m)", min_value=1.0, max_value=2.5, value=1.78)
bmi = st.number_input("BMI", min_value=10.0, max_value=50.0, value=25.2)
workout_type = st.selectbox("نوع تمرین", ["Cardio", "Strength", "HIIT", "Yoga"])
workout_freq = st.number_input("تعداد روزهای تمرین در هفته", min_value=0, max_value=7, value=4)
session_duration = st.number_input("مدت تمرین در هر جلسه (ساعت)", min_value=0.0, max_value=5.0, value=1.0)
calories_burned = st.number_input("کالری سوخته شده در تمرین", min_value=0, max_value=5000, value=450)
daily_calories = st.number_input("کل کالری دریافتی روزانه", min_value=1000, max_value=5000, value=2200)
carbs = st.number_input("کربوهیدرات روزانه (گرم)", min_value=0, max_value=1000, value=240)
proteins = st.number_input("پروتئین روزانه (گرم)", min_value=0, max_value=500, value=120)
fats = st.number_input("چربی روزانه (گرم)", min_value=0, max_value=300, value=60)
water_intake = st.number_input("مقدار آب مصرفی روزانه (لیتر)", min_value=0.0, max_value=10.0, value=2.5)
experience_level = st.selectbox("سطح تجربه تمرینی", [1, 2, 3], format_func=lambda x: {1:"Beginner",2:"Intermediate",3:"Advanced"}[x])

# --- دکمه پیش‌بینی ---
if st.button("پیش‌بینی درصد چربی"):
    new_user = pd.DataFrame([{
        "Age": age,
        "Gender": gender,
        "Weight (kg)": weight,
        "Height (m)": height,
        "BMI": bmi,
        "Workout_Type": workout_type,
        "Workout_Frequency (days/week)": workout_freq,
        "Session_Duration (hours)": session_duration,
        "Calories_Burned": calories_burned,
        "Calories": daily_calories,
        "Carbs": carbs,
        "Proteins": proteins,
        "Fats": fats,
        "Water_Intake (liters)": water_intake,
        "Experience_Level": experience_level
    }])

    prediction = model.predict(new_user)[0]
    st.success(f"🔹 درصد چربی پیش‌بینی‌شده: {prediction:.2f}%")
# Out:
# 2025-10-22 22:43:02.691 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.031
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\babak\.conda\envs\myenv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-10-22 22:43:03.032 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.035 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.036 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.037 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.039 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.040 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.043 Session state does not function when running a script without `streamlit run`
# 2025-10-22 22:43:03.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.046 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.051 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.052 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.053 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.057 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.058 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.060 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.061 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.078 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.083 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.095 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.096 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.098 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.102 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.104 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.105 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.107 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.109 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.114 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.115 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.116 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.122 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.127 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.130 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.132 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.133 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.138 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.145 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.146 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.148 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.149 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.150 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-10-22 22:43:03.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
